# %% [markdown]
# ## Imports

# %%
import tensorflow as tf
import gpt_2_simple as gpt2
import os
import re
import pandas as pd
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.

# %% [markdown]
# ## Functions

# %%
def read_txt_file(data_file):
    record = []
    with open(data_file, 'r') as f:
        for line in f:
            
            record.append(line)
    
    return record

# %%
def generate(data_row, run_name, temp, nsamples, batch_size):
    
    tf.reset_default_graph()
    session = gpt2.start_tf_sess()
    
    test_lst = data_row.split('<|endoftext|>\n')
    test_str = test_lst[0].split('[QUESTION]:')[0]
    
    pre = test_str + " [QUESTION]:"
    
    gpt2.load_gpt2(session, run_name = run_name)
    
    generated = gpt2.generate(session,
                  temperature = temp,
                  prefix= pre,
                  nsamples = nsamples,
                  batch_size = batch_size,
                  run_name = run_name,
                  return_as_list=True            
                  )
    
    return generated

# %% [markdown]
# ## Generation

# %%
data_file = 'data/squad_test.txt'

# %%
records = read_txt_file(data_file)

# %%
eval_df = pd.DataFrame(records, columns = ['Context'])

# %%
eval_df
# Out:
#                                                 Context
# 0     <|startoftext|> [CONTEXT]: The Normans (Norman...
# 1     <|startoftext|> [CONTEXT]: The Norman dynasty ...
# 2     <|startoftext|> [CONTEXT]: The English name "N...
# 3     <|startoftext|> [CONTEXT]: In the course of th...
# 4     <|startoftext|> [CONTEXT]: Before Rollo's arri...
# ...                                                 ...
# 1199  <|startoftext|> [CONTEXT]: where  is the mass ...
# 1200  <|startoftext|> [CONTEXT]: A conservative forc...
# 1201  <|startoftext|> [CONTEXT]: For certain physica...
# 1202  <|startoftext|> [CONTEXT]: The connection betw...
# 1203  <|startoftext|> [CONTEXT]: The pound-force has...
#
# [1204 rows x 1 columns]

# %%
# call generate function 

run_name = 'squad_ht_1' 
temp = 0.7 
nsamples = 5 
batch_size = 5

question_lst = [] 

for idx, row in eval_df.iterrows():
    print(idx)
    gen_lst = generate(row['Context'], run_name, temp, nsamples, batch_size)
    question_lst.append(gen_lst)
# Out:
# 0
# Loading checkpoint checkpoint/squad_ht_1/model-4000
# INFO:tensorflow:Restoring parameters from checkpoint/squad_ht_1/model-4000
# 1
# Loading checkpoint checkpoint/squad_ht_1/model-4000
# INFO:tensorflow:Restoring parameters from checkpoint/squad_ht_1/model-4000
# 2
# Loading checkpoint checkpoint/squad_ht_1/model-4000
# INFO:tensorflow:Restoring parameters from checkpoint/squad_ht_1/model-4000
# 3
# Loading checkpoint checkpoint/squad_ht_1/model-4000
# INFO:tensorflow:Restoring parameters from checkpoint/squad_ht_1/model-4000
# 4
# Loading checkpoint checkpoint/squad_ht_1/model-4000
# INFO:tensorflow:Restoring parameters from checkpoint/squad_ht_1/model-4000
# 5
# Loading checkpoint checkpoint/squad_ht_1/model-4000
# INFO:tensorflow:Restoring parameters from checkpoint/squad_ht_1/model-4000
# 6
# Loading checkpoint checkpoint/squad_ht_1/model-4000
# INFO:tensorflow:Restoring parameters from checkpoint/squad_ht_1/model-4000
# 7
# Loading checkpoint checkpoint/squad_ht_1/model-4000
# INFO:tensorflow:Restoring parameters from checkpoint/squad_ht_1/model-4000
# 8
# Loading checkpoint checkpoint/squad_ht_1/model-4000
# INFO:tensorflow:Restoring parameters from checkpoint/squad_ht_1/model-4000
# 9
# Loading checkpoint checkpoint/squad_ht_1/model-4000
# INFO:tensorflow:Restoring parameters from checkpoint/squad_ht_1/model-4000
# 10
# Loading checkpoint checkpoint/squad_ht_1/model-4000
# INFO:tensorflow:Restoring parameters from checkpoint/squad_ht_1/model-4000
# 11
# Loading checkpoint checkpoint/squad_ht_1/model-4000
# INFO:tensorflow:Restoring parameters from checkpoint/squad_ht_1/model-4000
# 12
# Loading checkpoint checkpoint/squad_ht_1/model-4000
# INFO:tensorflow:Restoring parameters from checkpoint/squad_ht_1/model-4000
# 13
# Loading checkpoint checkpoint/squad_ht_1/model-4000
# INFO:tensorflow:Restoring parameters from checkpoint/squad_ht_1/model-4000
# 14
# Loading checkpoint checkpoint/squad_ht_1/model-4000
# INFO:tensorflow:Restoring parameters from checkpoint/squad_ht_1/model-4000
# 15
# Loading checkpoint checkpoint/squad_ht_1/model-4000
# INFO:tensorflow:Restoring parameters from checkpoint/squad_ht_1/model-4000
# 16
# Loading checkpoint checkpoint/squad_ht_1/model-4000
# INFO:tensorflow:Restoring parameters from checkpoint/squad_ht_1/model-4000
# 17
# Loading checkpoint checkpoint/squad_ht_1/model-4000
# INFO:tensorflow:Restoring parameters from checkpoint/squad_ht_1/model-4000
# 18
# Loading checkpoint checkpoint/squad_ht_1/model-4000
# INFO:tensorflow:Restoring parameters from checkpoint/squad_ht_1/model-4000
# 19
# Loading checkpoint checkpoint/squad_ht_1/model-4000
# INFO:tensorflow:Restoring parameters from checkpoint/squad_ht_1/model-4000
# 20
# Loading checkpoint checkpoint/squad_ht_1/model-4000
# INFO:tensorflow:Restoring parameters from checkpoint/squad_ht_1/model-4000
# 21
# Loading checkpoint checkpoint/squad_ht_1/model-4000
# INFO:tensorflow:Restoring parameters from checkpoint/squad_ht_1/model-4000
# 22
# Loading checkpoint checkpoint/squad_ht_1/model-4000
# INFO:tensorflow:Restoring parameters from checkpoint/squad_ht_1/model-4000
# 23
# Loading checkpoint checkpoint/squad_ht_1/model-4000
# INFO:tensorflow:Restoring parameters from checkpoint/squad_ht_1/model-4000
# 24
# Loading checkpoint checkpoint/squad_ht_1/model-4000
# INFO:tensorflow:Restoring parameters from checkpoint/squad_ht_1/model-4000
# 25
# Loading checkpoint checkpoint/squad_ht_1/model-4000
# INFO:tensorflow:Restoring parameters from checkpoint/squad_ht_1/model-4000
# 26
# Loading checkpoint checkpoint/squad_ht_1/model-4000
# INFO:tensorflow:Restoring parameters from checkpoint/squad_ht_1/model-4000
# 27
# Loading checkpoint checkpoint/squad_ht_1/model-4000
# INFO:tensorflow:Restoring parameters from checkpoint/squad_ht_1/model-4000
# 28
# Loading checkpoint checkpoint/squad_ht_1/model-4000
# INFO:tensorflow:Restoring parameters from checkpoint/squad_ht_1/model-4000
# 29
# Loading checkpoint checkpoint/squad_ht_1/model-4000
# INFO:tensorflow:Restoring parameters from checkpoint/squad_ht_1/model-4000
# 30
# Loading checkpoint checkpoint/squad_ht_1/model-4000
# INFO:tensorflow:Restoring parameters from checkpoint/squad_ht_1/model-4000
# 31
# Loading checkpoint checkpoint/squad_ht_1/model-4000
# INFO:tensorflow:Restoring parameters from checkpoint/squad_ht_1/model-4000
# 32
# Loading checkpoint checkpoint/squad_ht_1/model-4000
# INFO:tensorflow:Restoring parameters from checkpoint/squad_ht_1/model-4000
# 33
# Loading checkpoint checkpoint/squad_ht_1/model-4000
# INFO:tensorflow:Restoring parameters from checkpoint/squad_ht_1/model-4000
# 34
# Loading checkpoint checkpoint/squad_ht_1/model-4000
# INFO:tensorflow:Restoring parameters from checkpoint/squad_ht_1/model-4000
# 35
# Loading checkpoint checkpoint/squad_ht_1/model-4000
# INFO:tensorflow:Restoring parameters from checkpoint/squad_ht_1/model-4000
# 36
# Loading checkpoint checkpoint/squad_ht_1/model-4000
# INFO:tensorflow:Restoring parameters from checkpoint/squad_ht_1/model-4000
# 37
# Loading checkpoint checkpoint/squad_ht_1/model-4000
# INFO:tensorflow:Restoring parameters from checkpoint/squad_ht_1/model-4000
# 38
# Loading checkpoint checkpoint/squad_ht_1/model-4000
# INFO:tensorflow:Restoring parameters from checkpoint/squad_ht_1/model-4000
# 39
# Loading checkpoint checkpoint/squad_ht_1/model-4000
# INFO:tensorflow:Restoring parameters from checkpoint/squad_ht_1/model-4000
# 40
# Loading checkpoint checkpoint/squad_ht_1/model-4000
# INFO:tensorflow:Restoring parameters from checkpoint/squad_ht_1/model-4000
# 41
# Loading checkpoint checkpoint/squad_ht_1/model-4000
# INFO:tensorflow:Restoring parameters from checkpoint/squad_ht_1/model-4000
# 42
# Loading checkpoint checkpoint/squad_ht_1/model-4000
# INFO:tensorflow:Restoring parameters from checkpoint/squad_ht_1/model-4000
# 43
# Loading checkpoint checkpoint/squad_ht_1/model-4000
# INFO:tensorflow:Restoring parameters from checkpoint/squad_ht_1/model-4000
# 44
# Loading checkpoint checkpoint/squad_ht_1/model-4000
# INFO:tensorflow:Restoring parameters from checkpoint/squad_ht_1/model-4000
# 45
# Loading checkpoint checkpoint/squad_ht_1/model-4000
# INFO:tensorflow:Restoring parameters from checkpoint/squad_ht_1/model-4000
# 46
# Loading checkpoint checkpoint/squad_ht_1/model-4000
# INFO:tensorflow:Restoring parameters from checkpoint/squad_ht_1/model-4000
# 47
# Loading checkpoint checkpoint/squad_ht_1/model-4000
# INFO:tensorflow:Restoring parameters from checkpoint/squad_ht_1/model-4000
# 48
# Loading checkpoint checkpoint/squad_ht_1/model-4000
# INFO:tensorflow:Restoring parameters from checkpoint/squad_ht_1/model-4000
# 49
# Loading checkpoint checkpoint/squad_ht_1/model-4000
# INFO:tensorflow:Restoring parameters from checkpoint/squad_ht_1/model-4000
# 50
# Loading checkpoint checkpoint/squad_ht_1/model-4000
# INFO:tensorflow:Restoring parameters from checkpoint/squad_ht_1/model-4000
# 51
# Loading checkpoint checkpoint/squad_ht_1/model-4000
# INFO:tensorflow:Restoring parameters from checkpoint/squad_ht_1/model-4000
# 52
# Loading checkpoint checkpoint/squad_ht_1/model-4000
# INFO:tensorflow:Restoring parameters from checkpoint/squad_ht_1/model-4000
# 53
# Loading checkpoint checkpoint/squad_ht_1/model-4000
# INFO:tensorflow:Restoring parameters from checkpoint/squad_ht_1/model-4000
# 54
# Loading checkpoint checkpoint/squad_ht_1/model-4000
# INFO:tensorflow:Restoring parameters from checkpoint/squad_ht_1/model-4000
# 55
# Loading checkpoint checkpoint/squad_ht_1/model-4000
# INFO:tensorflow:Restoring parameters from checkpoint/squad_ht_1/model-4000
# 56
# Loading checkpoint checkpoint/squad_ht_1/model-4000
# INFO:tensorflow:Restoring parameters from checkpoint/squad_ht_1/model-4000
# 57
# Loading checkpoint checkpoint/squad_ht_1/model-4000
# INFO:tensorflow:Restoring parameters from checkpoint/squad_ht_1/model-4000
# 58
# Loading checkpoint checkpoint/squad_ht_1/model-4000
# INFO:tensorflow:Restoring parameters from checkpoint/squad_ht_1/model-4000
# 59
# Loading checkpoint checkpoint/squad_ht_1/model-4000
# INFO:tensorflow:Restoring parameters from checkpoint/squad_ht_1/model-4000
# 60
# Loading checkpoint checkpoint/squad_ht_1/model-4000
# INFO:tensorflow:Restoring parameters from checkpoint/squad_ht_1/model-4000
# 61
# Loading checkpoint checkpoint/squad_ht_1/model-4000
# INFO:tensorflow:Restoring parameters from checkpoint/squad_ht_1/model-4000
# 62
# Loading checkpoint checkpoint/squad_ht_1/model-4000
# INFO:tensorflow:Restoring parameters from checkpoint/squad_ht_1/model-4000
# 63
# Loading checkpoint checkpoint/squad_ht_1/model-4000
# INFO:tensorflow:Restoring parameters from checkpoint/squad_ht_1/model-4000
# 64
# Loading checkpoint checkpoint/squad_ht_1/model-4000
# INFO:tensorflow:Restoring parameters from checkpoint/squad_ht_1/model-4000
# 65
# Loading checkpoint checkpoint/squad_ht_1/model-4000
# INFO:tensorflow:Restoring parameters from checkpoint/squad_ht_1/model-4000
# 66
# Loading checkpoint checkpoint/squad_ht_1/model-4000
# INFO:tensorflow:Restoring parameters from checkpoint/squad_ht_1/model-4000
# 67
# Loading checkpoint checkpoint/squad_ht_1/model-4000
# INFO:tensorflow:Restoring parameters from checkpoint/squad_ht_1/model-4000
# 68
# Loading checkpoint checkpoint/squad_ht_1/model-4000
# INFO:tensorflow:Restoring parameters from checkpoint/squad_ht_1/model-4000
# 69
# Loading checkpoint checkpoint/squad_ht_1/model-4000
# INFO:tensorflow:Restoring parameters from checkpoint/squad_ht_1/model-4000
# 70
# Loading checkpoint checkpoint/squad_ht_1/model-4000
# INFO:tensorflow:Restoring parameters from checkpoint/squad_ht_1/model-4000
# 71
# Loading checkpoint checkpoint/squad_ht_1/model-4000
# INFO:tensorflow:Restoring parameters from checkpoint/squad_ht_1/model-4000
# 72
# Loading checkpoint checkpoint/squad_ht_1/model-4000
# INFO:tensorflow:Restoring parameters from checkpoint/squad_ht_1/model-4000
# 73
# Loading checkpoint checkpoint/squad_ht_1/model-4000
# INFO:tensorflow:Restoring parameters from checkpoint/squad_ht_1/model-4000
# 74
# Loading checkpoint checkpoint/squad_ht_1/model-4000
# INFO:tensorflow:Restoring parameters from checkpoint/squad_ht_1/model-4000
# 75
# Loading checkpoint checkpoint/squad_ht_1/model-4000
# INFO:tensorflow:Restoring parameters from checkpoint/squad_ht_1/model-4000
# 76
# Loading checkpoint checkpoint/squad_ht_1/model-4000
# INFO:tensorflow:Restoring parameters from checkpoint/squad_ht_1/model-4000
# 77
# Loading checkpoint checkpoint/squad_ht_1/model-4000
# INFO:tensorflow:Restoring parameters from checkpoint/squad_ht_1/model-4000
# 78
# Loading checkpoint checkpoint/squad_ht_1/model-4000
# INFO:tensorflow:Restoring parameters from checkpoint/squad_ht_1/model-4000
# 79
# Loading checkpoint checkpoint/squad_ht_1/model-4000
# INFO:tensorflow:Restoring parameters from checkpoint/squad_ht_1/model-4000
# 80
# Loading checkpoint checkpoint/squad_ht_1/model-4000
# INFO:tensorflow:Restoring parameters from checkpoint/squad_ht_1/model-4000
# 81
# Loading checkpoint checkpoint/squad_ht_1/model-4000
# INFO:tensorflow:Restoring parameters from checkpoint/squad_ht_1/model-4000
# 82
# Loading checkpoint checkpoint/squad_ht_1/model-4000
# INFO:tensorflow:Restoring parameters from checkpoint/squad_ht_1/model-4000
# 83
# Loading checkpoint checkpoint/squad_ht_1/model-4000
# INFO:tensorflow:Restoring parameters from checkpoint/squad_ht_1/model-4000
# 84
# Loading checkpoint checkpoint/squad_ht_1/model-4000
# INFO:tensorflow:Restoring parameters from checkpoint/squad_ht_1/model-4000
# 85
# Loading checkpoint checkpoint/squad_ht_1/model-4000
# INFO:tensorflow:Restoring parameters from checkpoint/squad_ht_1/model-4000
# 86
# Loading checkpoint checkpoint/squad_ht_1/model-4000
# INFO:tensorflow:Restoring parameters from checkpoint/squad_ht_1/model-4000
# 87
# Loading checkpoint checkpoint/squad_ht_1/model-4000
# INFO:tensorflow:Restoring parameters from checkpoint/squad_ht_1/model-4000
# 88
# Loading checkpoint checkpoint/squad_ht_1/model-4000
# INFO:tensorflow:Restoring parameters from checkpoint/squad_ht_1/model-4000
# 89
# Loading checkpoint checkpoint/squad_ht_1/model-4000
# INFO:tensorflow:Restoring parameters from checkpoint/squad_ht_1/model-4000
#
# 1203  <|startoftext|> [CONTEXT]: The pound-force has...
#
#                                               Generated
# 0     [<|startoftext|> [CONTEXT]: The Normans (Norma...
# 1     [<|startoftext|> [CONTEXT]: The Norman dynasty...
# 2     [<|startoftext|> [CONTEXT]: The English name "...
# 3     [<|startoftext|> [CONTEXT]: In the course of t...
# 4     [<|startoftext|> [CONTEXT]: Before Rollo's arr...
# ...                                                 ...
# 1199  [<|startoftext|> [CONTEXT]: where  is the mass...
# 1200  [<|startoftext|> [CONTEXT]: A conservative for...
# 1201  [<|startoftext|> [CONTEXT]: For certain physic...
# 1202  [<|startoftext|> [CONTEXT]: The connection bet...
# 1203  [<|startoftext|> [CONTEXT]: The pound-force ha...
#
# [1204 rows x 2 columns]

# %%
question_col = []
for idx, item in eval_df.iterrows():
    questions = []
    item_lst = item['Generated'][0].split('<|startoftext|>')
    
    for string in item_lst[1:]:
        
        try:
            ques = re.search(r'\[QUESTION\]\:(.+?)<\|endoftext\|>', string).group(1)
            questions.append(ques)
        except:
            questions.append('None')
            print("No String")

    question_col.append(questions)
# Out:
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String
# No String

# %%
eval_df['Questions'] = question_col

# %%
context_clean = []
for idx, item in eval_df.iterrows():
    string = item['Context']
    try:
        con = re.search(r'\[CONTEXT\]\: (.+?)\[QUESTION\]\:', string).group(1)
        context_clean.append(con)
    except:
        print("No String")
        print(string)

# %%
final_questions = []
final_context = []

for idx, row in eval_df.iterrows():
    for item in row['Questions']:
        final_context.append(context_clean[idx])
        final_questions.append(item)

# %%
final_eval = pd.DataFrame({'Context' : final_context, 'Question' : final_questions})

# %%
final_eval
# Out:
#                                                 Context  \
# 0     The Normans (Norman: Nourmands; French: Norman...
# 1     The Normans (Norman: Nourmands; French: Norman...
# 2     The Normans (Norman: Nourmands; French: Norman...
# 3     The Normans (Norman: Nourmands; French: Norman...
# 4     The Normans (Norman: Nourmands; French: Norman...
# ...                                                 ...
# 6628  The pound-force has a metric counterpart, less...
# 6629  The pound-force has a metric counterpart, less...
# 6630  The pound-force has a metric counterpart, less...
# 6631  The pound-force has a metric counterpart, less...
# 6632  The pound-force has a metric counterpart, less...
#
#                                                Question
# 0               What is the first name of the Normans?
# 1        What was the first name given to the Normans?
# 2                   Who was the leader of the Normans?
# 3      What was the name of the nation that gave the...
# 4                      What did the Normans come from?
# ...                                                 ...
# 6628         What is the kilogram-force equivalent to?
# 6629                                  What is the mug?
# 6630                                 What is the ball?
# 6631                                  What is the kip?
# 6632                                               None
#
# [6633 rows x 2 columns]

# %%
final_eval.to_csv('squad_gen.csv')
